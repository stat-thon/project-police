# %% [markdown]
# # EDA for kp2021.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../data-police/KP2020.csv', encoding = 'CP949')
print(data.shape)
print(data.columns)
data.head(10)
# Out:
# (77077, 10)
# Index(['RECV_DEPT_NM', 'RECV_CPLT_DM', 'NPA_CL', 'EVT_STAT_CD', 'EVT_CL_CD',
#        'RPTER_SEX', 'HPPN_PNU_ADDR', 'HPPN_X', 'HPPN_Y', 'SME_EVT_YN'],
#       dtype='object')
#   RECV_DEPT_NM                 RECV_CPLT_DM  NPA_CL  EVT_STAT_CD  EVT_CL_CD  \
# 0          충남청  20/12/01 01:43:07.000000000      19           10        305
# 1          대전청  20/12/01 02:05:04.000000000      13           10        601
# 2          대전청  20/12/01 02:06:52.000000000      13           10        601
# 3          충남청  20/12/01 02:37:25.000000000      19           10        606
# 4          충남청  20/12/01 08:17:50.000000000      19           10        401
# 5          충남청  20/12/01 02:50:39.000000000      19           10        301
# 6          대전청  20/12/01 03:22:39.000000000      13           10        107
# 7          대전청  20/12/01 03:24:26.000000000      13           10        406
# 8          충남청  20/12/01 07:37:18.000000000      19           10        402
# 9          대전청  20/12/01 07:08:44.000000000      13           10        401
#
#    RPTER_SEX                     HPPN_PNU_ADDR      HPPN_X     HPPN_Y  \
# 0        1.0         충청남도 보령시 궁촌동(행정:대천4동) 369  126.598345  36.341537
# 1        3.0                               NaN  127.404663  36.341685
# 2        1.0                               NaN  127.404663  36.341685
# 3        3.0          충청남도 보령시 천북면 하만리 628-10   126.524980  36.474390
# 4        2.0    충청남도 천안시 서북구 성정동(행정:성정2동) 1259  127.137160  36.826718
# 5        2.0     충청남도 아산시 둔포면 석곡리(행정:둔포면) 1707  127.057462  36.920405
# 6        2.0      대전광역시 대덕구 중리동(행정:중리동) 381-25  127.422406  36.363326
# 7        1.0        대전광역시 유성구 봉명동(행정:온천1동) 575  127.341551  36.353696
# 8        1.0  충청남도 천안시 서북구 성환읍 성월리(행정:성환읍) 150  127.136142  36.917900
# 9        1.0           대전광역시 중구 석교동(석교동) 85-14  127.447545  36.306724
#
#   SME_EVT_YN
# 0          Y
# 1        NaN
# 2        NaN
# 3          N
# 4        NaN
# 5          Y
# 6          Y
# 7        NaN
# 8        NaN
# 9        NaN
